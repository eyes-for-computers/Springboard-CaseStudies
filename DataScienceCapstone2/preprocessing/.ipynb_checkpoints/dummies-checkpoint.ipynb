# %%
####################################################################################################
#################################__#########################################_ ######################               
###############################/ _|########################################| |######################               
#######  ___ _   _  ___  ___  | |##########################################| |_ ___ _ __ ___ #######
####### / _ \ | | |/ _ \/ __| |  _/ _ \| '__/ __/ _ \| '_ ` _ \| '_ \| | | | __/ _ \ '__/ __|#######
#######|  __/ |_| |  __/\__ \_| || (_) | |_| (_| (_) | | | | | | |_) | |_| | ||  __/ |  \__ \#######
###### \___|\__, |\___||___(_)_| \___/|_(_)\___\___/|_| |_| |_| .__/ \__,_|\__\___|_|  |___/#######
#############__/ |############################################| |###################################                           
############|___/ ############################################|_|###################################                           
####################################################################################################
#
# 
#
#
#

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('bx_appointments.xlsx', index_col='Client')

df.dtypes
df.shape
# Out:
# (1000, 9)

# %%
df.Day = df.Day.astype('category')
df['client'] = df.index

df['Staff Member'] = df['Staff Member'].astype('category')
df['Staff Member'].dtype

df['client'] = df['client'].astype('category')
df['client'].dtype
# Out:
# CategoricalDtype(categories=['client_0', 'client_1', 'client_2', 'client_3', 'client_4',
#                   'client_5', 'client_6', 'client_7', 'client_8'],
# , ordered=False)

# %%
# adding the sparse flag removed the 34GB memory error

dummies = pd.get_dummies(df['Staff Member'],df.client,df.Day, sparse=True)
dummies.sample(3)
# Out:
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_1  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_10  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_11  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_12  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_13  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_14  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  1
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_15  \
# Client
# client_2                                                  1
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_16  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_17  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_19  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           ...  \
# Client    ...
# client_2  ...
# client_8  ...
# client_5  ...
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_42  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_44  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_46  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_47  \
# Client
# client_2                                                  0
# ...
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_6  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_7  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_8  \
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_9
# Client
# client_2                                                  0
# client_8                                                  0
# client_5                                                  0
#
# [3 rows x 39 columns]

# %%
dummies.shape
# Out:
# (1000, 39)

# %%
# This merges dummies and the full df to be standarized
#
#

df = df.merge(dummies, left_index=True, right_index=True)

print(df.shape)
df.head(3)
# Out:
# (137392, 49)
#                Date Day Staff Member  Duration  aggression  elope  \
# Client
# client_0 2021-07-16   4      staff_8       4.0           1      0
# client_0 2021-07-16   4      staff_8       4.0           1      0
# client_0 2021-07-16   4      staff_8       4.0           1      0
#
#           non-compliance  protesting  sib    client  ...  \
# Client                                               ...
# client_0             6.0         0.0  9.0  client_0  ...
# client_0             6.0         0.0  9.0  client_0  ...
# client_0             6.0         0.0  9.0  client_0  ...
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_42  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_44  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_46  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_47  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_5  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_51  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_6  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_7  \
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_8  \
# Client
# client_0                                                  1
# client_0                                                  0
# client_0                                                  1
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_9
# Client
# client_0                                                  0
# client_0                                                  0
# client_0                                                  0
#
# [3 rows x 49 columns]

# %%
df_ss = ['aggression', 'elope', 'non-compliance', 'protesting', 'sib']

# Making a Scaler object

scaler = StandardScaler()

# Fitting data to the scaler object

scaled_df = scaler.fit_transform(df[df_ss])
scaled_df = pd.DataFrame(scaled_df, columns=df_ss)
scaled_df.head(3)
# Out:
#    aggression     elope  non-compliance  protesting       sib
# 0   -0.399086 -0.460239       -0.094702   -0.570422  2.000233
# 1   -0.399086 -0.460239       -0.094702   -0.570422  2.000233
# 2   -0.399086 -0.460239       -0.094702   -0.570422  2.000233

# %%
# already merged above

merged = df
for i in scaled_df.columns:
    merged[i] = scaled_df[i].values

merged.sample(3)
# Out:
#                Date Day Staff Member  Duration  aggression     elope  \
# Client
# client_4 2021-04-16   4      staff_6      1.25   -0.585974 -0.460239
# client_5 2021-06-25   4     staff_14      3.50   -0.585974  0.508188
# client_7 2021-03-12   4      staff_3      2.00   -0.585974 -0.460239
#
#           non-compliance  protesting       sib    client  ...  \
# Client                                                    ...
# client_4       -0.495307         NaN       NaN  client_4  ...
# client_5        0.572973         NaN       NaN  client_5  ...
# client_7             NaN         NaN -0.391761  client_7  ...
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_42  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_44  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_46  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_47  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_5  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_51  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_6  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_7  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_8  \
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
#           Client\nclient_0    client_0\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\nclient_1    client_1\n              ...   \nclient_6    client_6\nclient_8    client_8\nclient_0    client_0\nclient_7    client_7\nclient_6    client_6\nName: client, Length: 1000, dtype: category\nCategories (9, object): ['client_0', 'client_1', 'client_2', 'client_3', ..., 'client_5', 'client_6', 'client_7', 'client_8']Client\nclient_0    4\nclient_1    3\nclient_1    2\nclient_1    1\nclient_1    1\n           ..\nclient_6    1\nclient_8    0\nclient_0    0\nclient_7    0\nclient_6    0\nName: Day, Length: 1000, dtype: category\nCategories (5, int64): [0, 1, 2, 3, 4]staff_9
# Client
# client_4                                                  0
# client_5                                                  0
# client_7                                                  0
#
# [3 rows x 49 columns]

# %%
bx_list = ['aggression', 'elope', 'non-compliance', 'protesting', 'sib']


# Given a dataframe of clients and standarized behaviors, will return df with averages for each bx for each client
# This will probably not be used

def get_avgs(df, bx_list):
    
    new_index = list()
#    df_index = df.index.tolist()
    df_mean = pd.DataFrame()
    
    for i in df.index.unique():
        
        for b in bx_list:
            
            client_bx_mean = df.loc[df['client'] == i].mean()
            
            df_mean = df_mean.append(client_bx_mean, ignore_index = True)
            
            new_index.append(i)
    
    df_mean['client'] = new_index
    df_mean.set_index(df_mean.client)

    return df_mean, new_index
            
    
    
df_mean, new_index = get_avgs(merged,bx_list)
print('done')
# Out:
# <ipython-input-9-3f004420d2a1>:17: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   client_bx_mean = df.loc[df['client'] == i].mean()
# done

# %%
# Purpose: Create a df of observations where client showed their max instance of each bx
#          This is a dataset of the most extreme observations for each column and how they 
#          relate to other bx in the same session
#          
#
# Returns df of all clients where the observation with the instance of max bx_list
# The max frame is all of the category data as well as standarized bx
#
# Takes in a standarized df of client observations with dummies


def extreme_df(df):
    
    clients = df.index.unique()
    clients_max = pd.DataFrame()
    full_frame = pd.DataFrame()

    for i in clients:
    
        clients_frame = df.loc[df.client == i]
#    clients_frame = clients_frame[bx_list]
    
        for bx in bx_list:
    
            clients_max = clients_max.append(clients_frame[clients_frame[bx] == clients_frame[bx].max()].drop_duplicates())
#        full_frame = clients_max.append(clients_frame[clients_frame[bx] == clients_frame[bx]]) #max?

        print('done')
    return clients_max
    
clients_max = extreme_df(df)
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
len(clients_max)
# Out:
# 668

# %%
bx_list

cols_to_keep = ['Date', 'Day', 'Staff Member', 'Duration', 'aggression', 'elope', 'non-compliance', 'protesting', 'sib', 'client']

# %%
clients_max.to_csv('clients_max.csv')

# %%
# Purpose: Identify clients' that have had instances of bx more than 2 std from their mean.
#          Highlights what behaviors can be more extreme for a particular client.
#
#          If any clients bx is outside 2.5 std deviation of their mean, then we want that pointed out
#          Later: grab the full session row to use elsewhere

def flag_it(df):
    
    cols_to_keep = ['Problem','Date', 'Day', 'Staff Member', 'Duration', 'aggression', 'elope', 'non-compliance', 'protesting', 'sib', 'client']
    bx_list = ['aggression', 'elope', 'sib', 'non-compliance', 'protesting']
    extreme_obs = pd.DataFrame(columns=cols_to_keep)
    flags = pd.DataFrame(columns=['client', 'bx', 'mean','thresh'])
    extreme = []
    
    for c in df.client.unique():
        
        
        for bx in bx_list:
            
            bx_df = df.loc[df['client'] == c]
            client_bx_df = bx_df[bx]

            
            mean = client_bx_df.mean()
            std = client_bx_df.std()
            thresh = mean + std*2.5
                        
            extreme_obs = extreme_obs.append(bx_df.loc[bx_df[bx] > thresh])
            


            if client_bx_df.any() > thresh:
                flags = flags.append({'client' : c, 'bx' : bx, 'mean' : mean, 'thresh' : thresh}, ignore_index=True)

    
    extreme_obs = extreme_obs[cols_to_keep].drop_duplicates()
    

    return flags, extreme_obs
    
flags, extreme_obs = flag_it(df)
extreme_obs.reset_index()
# Out:
#        index Problem       Date Day Staff Member  Duration  aggression  \
# 0   client_0     NaN 2021-07-12   0     staff_23      6.00    0.722242
# 1   client_0     NaN 2021-06-29   1     staff_31      3.00    0.722242
# 2   client_0     NaN 2021-06-29   1     staff_33      4.00    0.722242
# 3   client_0     NaN 2021-05-28   4      staff_8      7.00    1.282906
# 4   client_0     NaN 2021-05-14   4     staff_41      6.00    1.096018
# ..       ...     ...        ...  ..          ...       ...         ...
# 90  client_8     NaN 2021-03-08   0      staff_2      3.50    2.217347
# 91  client_8     NaN 2021-05-12   2     staff_25      3.00   -0.399086
# 92  client_8     NaN 2021-05-12   2      staff_2      4.75   -0.399086
# 93  client_8     NaN 2021-04-16   4      staff_2      2.50   -0.585974
# 94  client_8     NaN 2021-02-17   2     staff_25      3.00   -0.585974
#
#        elope  non-compliance  protesting       sib    client
# 0  -0.460239        0.172368   -0.339360  2.797564  client_0
# 1   0.185379       -0.295005   -0.570422 -0.125984  client_0
# 2   0.185379       -0.295005   -0.570422 -0.125984  client_0
# 3  -0.460239       -0.495307   -0.570422  0.405570  client_0
# 4  -0.137430       -0.361772   -0.570422  0.937124  client_0
# ..       ...             ...         ...       ...       ...
# 90  0.185379             NaN         NaN       NaN  client_8
# 91  0.508188             NaN         NaN       NaN  client_8
# 92  0.508188             NaN         NaN       NaN  client_8
# 93  0.830997             NaN         NaN       NaN  client_8
# 94  0.508188             NaN         NaN       NaN  client_8
#
# [95 rows x 12 columns]

# %%
#extreme_obs.iloc[2].protesting - a

# %%
# function to gather the threshold from a client and bx

def get_thresh(client,bx):
    
    c = flags['client'] == client
    b = flags['bx'] == bx
    thresh = flags[c&b]['thresh']
    thresh = thresh
    
    return thresh

a = get_thresh('client_0','protesting')
a < extreme_obs.iloc[0]['protesting']
# Out:
# 2    False
# Name: thresh, dtype: bool

# %%
#count = 0 
for i in range(len(extreme_obs)):
    
    
    for client in extreme_obs['client'].unique():
        
        for bx in bx_list:
                        
            thresh = get_thresh(client,bx)
            
            obs = extreme_obs.iloc[i][bx]
            
            result = obs - thresh
            
            if obs.any() > thresh.any():
                
#                count += 1
#                print(count)
# Out:
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib
# elope
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# elope
# protesting
# sib
# protesting
# sib
# protesting
# sib
# aggression
# elope
# non-compliance
# protesting
# sib
# aggression
# elope
# protesting
# sib
# aggression
# non-compliance
# protesting
# non-compliance
# protesting
# sib

# %%
# Look at this with Ricardo
#for i in range(len(extreme_obs)):
'''

for client in extreme_obs['client']:
        
    for bx in bx_list:
        
        for i in range(len(extreme_obs)):
                        
            thresh = get_thresh(client,bx)
            
            obs = extreme_obs.iloc[i][bx]
            
            result = obs - thresh
            
            if obs.item() > thresh.item():
                
                print(bx)
                
'''
# Out:
# "\n\nfor client in extreme_obs['client']:\n        \n    for bx in bx_list:\n        \n        for i in range(len(extreme_obs)):\n                        \n            thresh = get_thresh(client,bx)\n            \n            obs = extreme_obs.iloc[i][bx]\n            \n            result = obs - thresh\n            \n            if obs.item() > thresh.item():\n                \n                print(bx)\n                \n"

# %%
flags
# Out:
#       client              bx      mean    thresh
# 0   client_0      aggression -0.378176  0.607342
# 1   client_0  non-compliance -0.365041  0.184279
# 2   client_0      protesting -0.445196 -0.037085
# 3   client_2      aggression -0.257505  0.980178
# 4   client_2  non-compliance -0.182208  0.537264
# 5   client_3      aggression -0.561384 -0.306105
# 6   client_3           elope -0.388031  0.129070
# 7   client_3  non-compliance -0.394277  0.037728
# 8   client_4      aggression -0.514094 -0.163318
# 9   client_4           elope -0.360913  0.176729
# 10  client_4  non-compliance -0.364982  0.142377
# 11  client_6  non-compliance -0.295005  0.359689
# 12  client_7           elope -0.322648  0.577672
# 13  client_7             sib -0.295907  0.749726
# 14  client_8      aggression -0.422743  0.581251
# 15  client_8           elope -0.264102  0.489276

# %%
# When I have 'problem filled in I can run a few graphs showing sorting by staff and client 

sns.heatmap(extreme_obs[bx_list])
# Out:
# <AxesSubplot:>

# %%
# Can plot client/staff by bx
# Should not reduce dimentionality of client/staff. Each point is important

plt.rcParams['figure.figsize'] = [10, 10]

a = extreme_obs['client'] == 'client_0'
plt.title('Showing a client with observations of their bx')

plt.scatter(a,extreme_obs['elope'] )

# %%
'''

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axes
z = extreme_obs['elope']
x = extreme_obs['sib']
y = extreme_obs['Staff Member']
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot geeks for geeks')
plt.show()

'''
# Out:
# "\n\nfig = plt.figure()\n \n# syntax for 3-D projection\nax = plt.axes(projection ='3d')\n \n# defining all 3 axes\nz = extreme_obs['elope']\nx = extreme_obs['sib']\ny = extreme_obs['Staff Member']\n \n# plotting\nax.plot3D(x, y, z, 'green')\nax.set_title('3D line plot geeks for geeks')\nplt.show()\n\n"

# %%
flags[flags.client == 'client_0']
# Out:
#      client              bx      mean    thresh
# 0  client_0      aggression -0.378176  0.607342
# 1  client_0  non-compliance -0.365041  0.184279
# 2  client_0      protesting -0.445196 -0.037085

# %%
print('Original df size: ' + str(len(df.drop_duplicates())))
print('extreme_obs size: ' + str(len(extreme_obs.drop_duplicates())))
# Out:
# Original df size: 9840
# extreme_obs size: 95

# %%
client_extreme = pd.DataFrame(columns=['client','entries']) # add bx col

for c in extreme_obs.client.unique():#extreme_obs.index.unique():
    
    aa = pd.DataFrame(extreme_obs.loc[extreme_obs.client == c])
    l = len(extreme_obs.loc[extreme_obs.client == c])
    
   
    client_extreme = client_extreme.append({'client' : c, 'entries' : l}, ignore_index=True).sort_values(by='entries', ascending=False)
    
client_extreme
# Out:
#      client entries
# 0  client_0      26
# 1  client_7      19
# 2  client_2      14
# 3  client_3      11
# 4  client_1       6
# 5  client_4       6
# 8  client_8       5
# 6  client_5       4
# 7  client_6       4

# %%
staff_extreme = pd.DataFrame(columns=['staff','entries']) 

for c in extreme_obs['Staff Member'].unique():
    
    aa = pd.DataFrame(extreme_obs.loc[extreme_obs['Staff Member'] == c])
    l = len(extreme_obs.loc[extreme_obs['Staff Member'] == c])
    
   
    staff_extreme = staff_extreme.append({'staff' : c, 'entries' : l}, ignore_index=True).sort_values(by='entries', ascending=False)
    
    staff_extreme = staff_extreme[staff_extreme['entries']  > 4]

# %%
#
# This DBSCAN model has defined the same number of outliers as my original formula did
# It also crashed the kernel 95% of the time...


from sklearn.cluster import DBSCAN

eo = extreme_obs.fillna(extreme_obs[bx_list].mean())

data = eo[bx_list]

model = DBSCAN(eps = 0.4, min_samples = 20).fit(data)



colors = model.labels_
plot = plt.scatter(data["elope"], data['protesting'], c = colors)

plt.show()

# %%
outliers = data[model.labels_ == -1]

outliers = outliers.drop_duplicates()


print(len(outliers), outliers)
# Out:
# 59           aggression     elope  non-compliance  protesting       sib
# client_0    0.722242 -0.460239        0.172368   -0.339360  2.797564
# client_0    0.722242  0.185379       -0.295005   -0.570422 -0.125984
# client_0    1.282906 -0.460239       -0.495307   -0.570422  0.405570
# client_0    1.096018 -0.137430       -0.361772   -0.570422  0.937124
# client_0    0.722242  0.830997        0.439438   -0.223829  1.734456
# client_0   -0.585974  2.767851       -0.094702    0.180529 -0.391761
# client_0   -0.585974  4.704705        0.105600   -0.050533  5.455334
# client_0   -0.399086  2.767851       -0.495307   -0.397125  0.937124
# client_0   -0.585974  3.413469       -0.161470   -0.570422  1.734456
# client_0   -0.399086 -0.460239       -0.228237   -0.397125  4.392226
# client_0   -0.585974 -0.137430       -0.495307   -0.454891  6.252665
# client_0   -0.585974 -0.137430        0.906810   -0.570422 -0.391761
# client_0   -0.399086 -0.460239        0.706508   -0.570422 -0.391761
# client_0   -0.399086 -0.137430       -0.161470    0.007233 -0.391761
# client_0   -0.585974 -0.460239        0.172368    0.007233 -0.391761
# client_0    0.535354 -0.460239       -0.228237    0.007233  2.000233
# client_0    0.161578 -0.460239       -0.295005    0.122764  1.734456
# client_1    3.899339  1.799424        0.122035    4.224113  1.610426
# client_1   -0.212198  8.578412        0.122035    2.317852  1.610426
# client_1   -0.585974  8.578412        0.122035    3.761989  1.610426
# client_2    1.282906 -0.460239       -0.094702    0.416405  1.610426
# client_2    1.096018  0.508188        0.172368    0.416405  1.610426
# client_2    1.469794  0.508188       -0.027935    0.416405  1.610426
# client_2    1.096018  0.508188       -0.295005    0.416405  1.610426
# client_2   -0.585974  6.964367        0.105600    0.416405  1.610426
# client_2   -0.025310  5.673131        0.239135    0.416405  1.610426
# client_2   -0.585974  0.185379        0.639740    0.416405  1.610426
# client_2    0.722242  0.508188        0.706508    0.416405  1.610426
# client_3   -0.212198 -0.460239       -0.495307    0.416405 -0.391761
# client_3    0.161578  0.185379       -0.295005    0.416405  1.468679
# client_3   -0.585974  0.508188       -0.495307    0.416405  0.405570
# client_3   -0.585974  0.185379       -0.428540    0.416405 -0.391761
# client_3   -0.399086  0.185379       -0.228237    0.416405 -0.125984
# client_3   -0.585974 -0.460239        0.239135    0.416405  3.860672
# client_3   -0.399086 -0.460239        0.172368    0.416405  3.594895
# client_3   -0.585974 -0.137430       -0.295005    0.416405  3.860672
# client_3   -0.585974 -0.460239        0.239135    0.416405 -0.391761
# client_3   -0.585974 -0.460239        0.239135    0.416405  1.734456
# client_4   -0.025310 -0.460239       -0.361772    0.416405  1.610426
# client_4   -0.025310 -0.460239       -0.495307    0.416405  1.610426
# client_4   -0.585974  0.830997        0.706508    0.416405  1.610426
# client_5    2.778011  0.185379        2.175392    0.416405  1.610426
# client_5    2.030459  4.381896        2.442462    0.416405  1.610426
# client_6    3.712451  2.767851       -0.495307    0.700419  2.266010
# client_6    0.348466  0.508188       -0.495307    0.411591  9.176212
# client_6    1.843571  0.185379        0.840043   -0.339360  4.658003
# client_6    0.348466 -0.137430        0.439438    0.180529  0.139793
# client_7    5.020668 -0.460239        0.122035    0.416405 -0.391761
# client_7    3.899339  0.185379        0.122035    0.416405  2.531787
# client_7    4.273115 -0.460239        0.122035    0.416405  0.671347
# client_7    5.020668 -0.460239        0.122035    0.416405  2.531787
# client_7   -0.585974  0.830997        0.122035    0.416405 -0.391761
# client_7   -0.585974  3.090660        0.122035    0.416405 -0.391761
# client_7   -0.399086  1.476615        0.122035    0.416405 -0.391761
# client_7   -0.212198 -0.137430        0.122035    0.416405  0.937124
# client_8    2.217347  0.185379        0.122035    0.416405  1.610426
# client_8   -0.399086  0.508188        0.122035    0.416405  1.610426
# client_8   -0.585974  0.830997        0.122035    0.416405  1.610426
# client_8   -0.585974  0.508188        0.122035    0.416405  1.610426

# %%
len(outliers.loc[outliers.index == 'client_0'])
# Out:
# 17

# %%
#colors = model.labels_
#plt.scatter(data["elope"], data["protesting"], c = colors)

# %%
c7 = extreme_obs['client'] == 'client_0'

extreme_obs[c7]

sns.heatmap(extreme_obs[c7][bx_list])

#sns.heatmap(extreme_obs[bx_list)

# %%
client_elope = plt.scatter(extreme_obs['client'],extreme_obs['elope'])
plt.title('Distribution of observed instances of elope by client')
plt.ylabel('BX: elope')
plt.show()

# %%
client_elope = plt.scatter(extreme_obs['client'],extreme_obs['elope'])
plt.title('Distribution of observed instances of elope by client')
plt.ylabel('BX: elope')
plt.show()

# %%
client_elope = plt.scatter(extreme_obs['Staff Member'],extreme_obs['elope'])

#client_elope = client_elope['elope'] > .4
plt.title('Distribution of observed instances of elope by Staff Member')
plt.ylabel('BX: elope')
plt.show()

# %%
plt.scatter(staff_extreme['staff'],staff_extreme['entries'])

# %%
plt.bar(extreme_obs['client'],extreme_obs['aggression'])

# %%
'''

staff_extreme = pd.DataFrame(columns=['Staff Member','entries']) # add bx col
nums = pd.DataFrame()

for c in extreme_obs['Staff Member'].unique():#extreme_obs.index.unique():
    
    l = len(extreme_obs.loc[extreme_obs['Staff Member'] == c])
    
    staff_extreme = nums.append({'Staff Member' : c, 'entries' : l}, ignore_index=True).sort_values(by='entries', ascending=False)

staff_extreme    

'''

# %%
flags

# %%
df.sample(10)

# %%
#  What can I do with many categorical dummy variables to detect things like 
#  If a single staff observes more of a specific behavior across all of their sessions

# Need a df of all the outlier sessions
